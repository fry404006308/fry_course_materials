# %% [markdown]
# # 一、opencv是干啥的

# %% [markdown]
# OpenCV的全称是Open Source Computer Vision Library，是一个跨平台的`计算机视觉库`。OpenCV是由英特尔公司发起并参与开发，以BSD许可证授权发行，`可以在商业和研究领域中免费使用`。OpenCV可用于开发实时的图像处理、计算机视觉以及模式识别程序。该程序库也可以使用英特尔公司的IPP进行加速处理。
#
# OpenCV - 维基百科，自由的百科全书
#
# https://zh.wikipedia.org/zh-hans/OpenCV

# %% [markdown]
# # 二、课程设计初衷

# %% [markdown]
# 1、【免费高效】想给大家带来免费高效的课程，课件和代码直接放到我的github仓库中，大家要用对应的功能的时候，直接复制粘贴我的代码，使用非常非常简单
#
# ```
# https://github.com/fry404006308/fry_course_materials
# ```
#
# 2、【给大家节约时间】B站上面的opencv课程动则十几个小时，而入门，学会使用常用的api，半个小时一个小时就可以了。
#
# 当然，老师带进门，修行靠个人
#
# 3、【进阶功能】进阶需求可以直接在视频下方留言，我根据你们的需求，后面会录：比如opencv-c++版本，具体工业领域的项目实战，精度方面比如亚像素边缘检测，亚像素模板匹配等等，速度方面比如cuda加速改写opencv算子等等

# %% [markdown]
# # 三、python如何安装opencv

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# asttokens                     2.2.1
# astunparse                    1.6.3
# attrs                         22.2.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# cachetools                    5.3.0
# certifi                       2022.12.7
# charset-normalizer            3.0.1
# click                         8.1.3
# colorama                      0.4.6
# ConfigArgParse                1.5.3
# contourpy                     1.0.7
# cycler                        0.11.0
# dash                          2.9.1
# dash-core-components          2.0.0
# dash-html-components          2.0.0
# dash-table                    5.0.0
# debugpy                       1.5.1
# decorator                     5.1.1
# executing                     1.2.0
# fastjsonschema                2.16.3
# Flask                         2.2.3
# flatbuffers                   23.1.21
# fonttools                     4.38.0
# gast                          0.4.0
# google-auth                   2.16.1
# google-auth-oauthlib          0.4.6
# google-pasta                  0.2.0
# grpcio                        1.51.3
# h5py                          3.8.0
# idna                          3.4
# imgviz                        1.7.2
# importlib-metadata            6.0.0
# importlib-resources           5.12.0
# ipykernel                     6.15.0
# ipython                       8.11.0
# ipywidgets                    8.0.4
# itsdangerous                  2.1.2
# jedi                          0.18.2
# Jinja2                        3.1.2
# joblib                        1.2.0
# jsonschema                    4.17.3
# jupyter_client                8.0.3
# jupyter_core                  5.2.0
# jupyterlab-widgets            3.0.5
# keras                         2.11.0
# kiwisolver                    1.4.4
# labelme                       5.2.0.post4
# libclang                      15.0.6.1
# Markdown                      3.4.1
# MarkupSafe                    2.1.2
# matplotlib                    3.7.0
# matplotlib-inline             0.1.6
# natsort                       8.3.1
# nbformat                      5.7.0
# nest-asyncio                  1.5.6
# ninja                         1.11.1
# numpy                         1.24.2
# oauthlib                      3.2.2
# open3d                        0.17.0
# opencv-python                 4.7.0.72
# opt-einsum                    3.3.0
# packaging                     23.0
# parso                         0.8.3
# pickleshare                   0.7.5
# Pillow                        9.4.0
# pip                           22.3.1
# platformdirs                  3.1.0
# plotly                        5.13.1
# prompt-toolkit                3.0.38
# protobuf                      3.19.6
# psutil                        5.9.0
# pure-eval                     0.2.2
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# Pygments                      2.14.0
# pyparsing                     3.0.9
# PyQt5                         5.15.9
# PyQt5-Qt5                     5.15.2
# PyQt5-sip                     12.12.0
# pyrsistent                    0.19.3
# pytesseract                   0.3.10
# python-dateutil               2.8.2
# pywin32                       227
# PyYAML                        6.0
# pyzmq                         23.2.0
# QtPy                          2.3.1
# requests                      2.28.2
# requests-oauthlib             1.3.1
# rsa                           4.9
# scikit-learn                  1.2.1
# scipy                         1.10.1
# setuptools                    65.6.3
# six                           1.16.0
# sklearn                       0.0.post1
# stack-data                    0.6.2
# tabulate                      0.9.0
# tenacity                      8.2.2
# tensorboard                   2.11.2
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorboardX                  2.6
# tensorflow                    2.11.0
# tensorflow-estimator          2.11.0
# tensorflow-intel              2.11.0
# tensorflow-io-gcs-filesystem  0.31.0
# termcolor                     2.2.0
# thop                          0.1.1.post2209072238
# threadpoolctl                 3.1.0
# torch                         1.13.1+cu116
# torchaudio                    0.13.1+cu116
# torchvision                   0.14.1+cu116
# tornado                       6.2
# tqdm                          4.65.0
# traitlets                     5.9.0
# typing_extensions             4.5.0
# urllib3                       1.26.14
# wcwidth                       0.2.6
# Werkzeug                      2.2.3
# wheel                         0.38.4
# widgetsnbextension            4.0.5
# wincertstore                  0.2
# wrapt                         1.15.0
# zipp                          3.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: opencv-python in c:\users\40400\.conda\envs\pytorch_1_13_2\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\40400\.conda\envs\pytorch_1_13_2\lib\site-packages (from opencv-python) (1.24.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 四、课程大纲（初步）

# %% [markdown]
# ## 课程介绍
#
# 【0-1】、课程介绍及 opencv -python安装
#
# ## 一、转化
#
# 【1-1】、3 分钟学会彩色图片转灰度图-opencv
#
# 【1-2】、3 分钟学会图像二值化-opencv
#
# 【1-3】、3 分钟学会给灰度图着色-opencv
#
# ## 二、写画
#
# 【2-1】、3 分钟在图像上面写汉字-opencv
#
# 【2-2】、3 分钟学会在图像上面画各种图形-opencv
#
# ## 三、变换
#
# 【3-1】、3 分钟学会改变图像尺寸-opencv
#
# 【3-2】、3 分钟学会旋转图片-opencv
#
# 【3-3】、3 分钟学会翻转图片-opencv
#
# 【3-4】、3 分钟学会图片仿射变换-opencv
#
# ## 四、融合
#
# 【4-1】、3 分钟学会融合多张图片-opencv
#
# ## 五、去噪
#
# 【5-1】、3分钟学会去除图像噪声-高斯滤波-opencv
#
# 【5-2】、3分钟学会去除图像噪声-中值滤波-opencv
#
# ## 六、梯度、边缘、轮廓
#
# 【6-1】、3 分钟学会求图像的梯度-opencv
#
# 【6-2】、3 分钟学会求图像的边缘-opencv
#
# 【6-3】、3 分钟学会求图像的轮廓-opencv
#
# 【6-4】、3 分钟学会画图像的外接矩形-opencv
#
# ## 七、模板匹配
#
# 【7-1】、3分钟学会模板匹配-opencv
#
# ## 八、连通域分析
#
# 【8-1】、4分钟学会求图像的连通域-opencv
#
# ## 九、直方图均衡
#
# 【9-1】、3分钟学会增强图片特征细节-直方图均衡-opencv
#
# ## 十、形态学
#
# 【10-1】、3分钟学会图片的膨胀-opencv
#
# 【10-2】、3分钟学会图片的腐蚀-opencv
#
# ## 十一、直线拟合
#
# 【11-1】、3分钟学会直线拟合-opencv
#
# ## 十二、检测直线和圆
#
# 【12-1】、3分钟学会检测图片中的直线-opencv
#
# 【12-2】、3分钟学会检测图片中的圆-opencv
#
# ## 说明：
#
# 一些其它的我没讲，比如角点检测、傅里叶变换、曲面拟合等等功能，大家需要用的时候自行查找API既可
