# %% [markdown]
# # <div style="color:red;text-align:center;">python超简单实用爬虫操作</div>

# %% [markdown]
# ## 一、爬虫介绍

# %% [markdown]
# **爬虫介绍**
#
# 爬虫就是自动获取网页内容的程序
#
# google、百度等搜索引擎本质就是爬虫
#
# <img src="./搜索引擎原理.png" style="width:100%;height:100%;text-align:center" />
#
# 虽然大部分编程语言几乎都能做爬虫，但是做爬虫最火的编程语言还是python
#
# python中爬取网页的库有python自带的urllib，还有第三方库requests等，
#
# requests这个库是基于urllib，功能都差不多，但是操作啥的要简单方便特别多
#
# >Requests is an elegant and simple HTTP library for Python, built for human beings.
#
# ---
#
# **爬虫实例**
#
# 比如我的网站  https://fanrenyi.com
#
# 比如电影天堂 等等
#
# ---
#
# **课程介绍**
#
# 讲解python爬虫操作中特别常用的操作，比如爬取网页、post方式爬取网页、模拟登录爬取网页等等

# %% [markdown]
# ## 二、爬虫基本操作

# %%
# 安装requests库
# pip3 install requests
# 引入requests库
# import requests

# %%
import requests
# 爬取博客园博客数据
response = requests.get("https://www.cnblogs.com/Renyi-Fan/p/13264726.html")
print(response.status_code)
# print(response.text)
# Out:
# 200

# %%
import requests
# 爬取知乎数据
headers = {
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36"
}
response = requests.get("https://www.zhihu.com/",headers=headers)
print(response.status_code)
#print(response.text)
# Out:
# 200

# %%
import requests
response = requests.get("http://httpbin.org/get")
print(response.text)
# "User-Agent": "python-requests/2.22.0",
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0",
#     "X-Amzn-Trace-Id": "Root=1-5f0519fc-c5562180e38514b668891480"
#   },
#   "origin": "119.86.158.170",
#   "url": "http://httpbin.org/get"
# }

# %% [markdown]
# ## 三、获取各种请求数据

# %%
import requests
response = requests.get('http://httpbin.org/get')
response = requests.post('http://httpbin.org/post', data = {'key':'value'})
response = requests.put('http://httpbin.org/put', data = {'key':'value'})
response = requests.delete('http://httpbin.org/delete')
response = requests.head('http://httpbin.org/get')
response = requests.options('http://httpbin.org/get')

# %%
import requests
response = requests.post('http://httpbin.org/post', data = {'key':'value'})
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0",
#     "X-Amzn-Trace-Id": "Root=1-5f05ee86-26bd986d7947684573f04544"
#   },
#   "json": null,
#   "origin": "119.86.155.123",
#   "url": "http://httpbin.org/post"
# }

# %%
# 爬取拉勾网的post请求数据
url = "https://www.lagou.com/jobs/positionAjax.json?gj=%E4%B8%8D%E8%A6%81%E6%B1%82&px=default&needAddtionalResult=false"
headers = {
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36",
    "referer":"https://www.lagou.com/jobs/list_Python/p-city_0?px=default&gj=%E4%B8%8D%E8%A6%81%E6%B1%82"
}
# 用session对象，可以保持cookie等参数的一致
session = requests.Session()
response = session.get("https://www.lagou.com/jobs/list_Python/p-city_0?px=default&gj=%E4%B8%8D%E8%A6%81%E6%B1%82#filterBox",headers=headers)
print(response.cookies)
response = session.post(url,cookies=response.cookies,headers=headers)
print(response.text)
# Out:
# <RequestsCookieJar[<Cookie X_HTTP_TOKEN=42daf4b72327b2814105224951bf5e71415983ed09 for .lagou.com/>, <Cookie user_trace_token=20200709001654-1af24ccc-70ba-4943-a6a9-0d302291065a for .lagou.com/>, <Cookie JSESSIONID=ABAAABAABEIABCIFF6F55A84F031C8D1E06EAE43C10EA91 for www.lagou.com/>, <Cookie SEARCH_ID=3a1dcad183514b3293f637d550e507dc for www.lagou.com/>]>
# {"success":true,"msg":null,"code":0,"content":{"showId":"518edec4f1bf483aa28c0f87b2fccca4","hrInfoMap":{"7392496":{"userId":4663005,"portrait":"i/image/M00/20/F3/Ciqc1F7pl_GAHzGMAAAu84IMpx4255.png","realName":"Aedio","positionName":"人事经理","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"7340913":{"userId":17920840,"portrait":"i/image2/M01/0E/AC/CgotOVyhgdKAWLwZAACHltqNgkc507.png","realName":"林俞材","positionName":"人事经理","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"7234863":{"userId":4214197,"portrait":"i/image2/M01/BF/ED/CgoB5lwtYtWAf3p3AAB8a4IPtg4235.jpg","realName":"刘先生","positionName":"高级招聘专员/HR","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"7186348":{"userId":3957550,"portrait":null,"realName":"yans","positionName":null,"phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"7256040":{"userId":17638530,"portrait":"i/image2/M01/0E/8C/CgoB5lyhgdiAN-4AAACeGEp-ay0931.png","realName":"李小姐","positionName":"人事经理","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"7399415":{"userId":83376,"portrait":"i/image2/M01/18/2A/CgoB5lyvHTiAM7jIAACiY2jIUbA580.jpg","realName":"蓝狮科技","positionName":"CEO","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"6868675":{"userId":5377005,"portrait":"i/image3/M01/6D/C7/CgpOIF5eG3OAOs6aAAI4025F3Tw468.jpg","realName":"刘颖","positionName":"创始人","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"7376992":{"userId":17948648,"portrait":"i/image/M00/28/65/Ciqc1F74pf6AaEkTAACewIkSPUw018.png","realName":"冉敏","positionName":"普工","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"7378370":{"userId":5279876,"portrait":"i/image/M00/2B/E8/Ciqc1F7_UAuAbTIyAADDIgNYRzk732.png","realName":"李先生","positionName":"城市经理","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"4874846":{"userId":6695820,"portrait":null,"realName":"吴HR","positionName":"招聘经理","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"6972755":{"userId":8023287,"portrait":"i/image2/M01/A9/1B/CgoB5lvo--KAYLnOAAMnhEr_DCI550.png","realName":"Teletraan HR","positionName":"HR","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"6887509":{"userId":811225,"portrait":"i/image2/M01/E2/6A/CgotOVxurbmAXvw2AACePFg7b1E166.jpg","realName":"平安科技HR","positionName":"","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"6917652":{"userId":2487918,"portrait":"i/image2/M00/48/41/CgotOVregCWAEJyfAACadFenrkI390.jpg","realName":"Owen","positionName":"招聘经理","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"7090225":{"userId":4163206,"portrait":null,"realName":"HR","positionName":"招聘管理岗","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"6448732":{"userId":17034211,"portrait":null,"realName":"张皓哲","positionName":"招聘经理","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true}},"pageNo":1,"positionResult":{"resultSize":15,"result":[{"positionId":6972755,"positionName":"机器视觉工程师","companyId":211574,"companyFullName":"浙江天垂科技有限公司","companyShortName":"TELETRAAN","companyLogo":"i/image/M00/0F/40/CgqCHl7HROOAY7S2AAKz-s1_Scw842.jpg","companySize":"15-50人","industryField":"数据服务,企业服务","financeStage":"天使轮","companyLabelList":["硅谷技术","MAC环境","股票期权","绩效奖金"],"firstType":"开发|测试|运维类","secondType":"数据开发","thirdType":"机器学习","skillLables":["算法","数据挖掘"],"positionLables":["大数据","算法","数据挖掘"],"industryLables":["大数据","算法","数据挖掘"],"createTime":"2020-07-09 00:12:41","formatCreateTime":"00:12发布","city":"杭州","district":"滨江区","businessZones":["西兴"],"salary":"13k-26k","salaryMonth":"0","workYear":"不限","jobNature":"全职","education":"本科","positionAdvantage":"弹性工作,硅谷团队,股权激励,全正版软件","imState":"disabled","lastLogin":"2020-07-08 23:55:57","publisherId":8023287,"approve":1,"subwayline":"1号线","stationname":"滨和路","linestaion":"1号线_滨和路;1号线_江陵路;1号线_滨和路;1号线_江陵路","latitude":"30.20856","longitude":"120.211816","distance":null,"hitags":null,"resumeProcessRate":100,"resumeProcessDay":2,"score":1," ...

# %% [markdown]
# ## 四、爬取图片

# %%
import requests
headers = {
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36",
}
url ="https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1594286367651&di=7f176da3578634bc67e5f38e24438b0c&imgtype=0&src=http%3A%2F%2Fbpic.588ku.com%2Felement_origin_min_pic%2F16%2F07%2F10%2F205782447d16b2a.jpg%2521%2Ffwfh%2F804x804%2Fquality%2F90%2Funsharp%2Ftrue%2Fcompress%2Ftrue"
response = requests.get(url,headers=headers)
print(response.status_code)
# print(response.text)
# print(response.content)
with open("test.jpg","wb") as f:
    f.write(response.content)
# Out:
# 200

# %% [markdown]
# ## 五、爬取视频

# %%
import requests
headers = {
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36",
}
url ="https://video.pearvideo.com/mp4/adshort/20200709/cont-1684816-15252785_adpkg-ad_hd.mp4"
response = requests.get(url,headers=headers)
print(response.status_code)
# print(response.text)
# print(response.content)
with open("v.mp4","wb") as f:
    f.write(response.content)
    print("下载完成")
# Out:
# 200
# 下载完成

# %%
# 用流的方式来爬视频
import requests
headers = {
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36",
}
url ="https://video.pearvideo.com/mp4/adshort/20200709/cont-1684816-15252785_adpkg-ad_hd.mp4"
response = requests.get(url,headers=headers,stream=True)
print(response.status_code)
# print(response.text)
# print(response.content)
with open("v.mp4","wb") as f:
    for i in response.iter_content(chunk_size=1024):
        f.write(i)
    print("下载完成")
# Out:
# 200
# 下载完成

# %%
# 显示下载视频的进度
import requests
headers = {
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36",
}
url ="https://video.pearvideo.com/mp4/adshort/20200709/cont-1684816-15252785_adpkg-ad_hd.mp4"
response = requests.get(url,headers=headers,stream=True)
print(response.status_code)
print(response.headers['content-length'])
content_size = int(response.headers['content-length'])
# print(response.text)
# print(response.content)
n = 1
with open("v.mp4","wb") as f:
    for i in response.iter_content(chunk_size=1024):
        rate=n*1024/content_size
        # print("下载进度：{0:%}".format(rate))
        f.write(i)
        n+=1
    print("下载完成")
# Out:
# 200
# 12890207
# 下载完成

# %% [markdown]
# ## 六、模拟登录获取数据

# %%
import requests
headers = {
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36",
}
cookies={
    "_ga":"GA1.2.1718512095.1585155221",
    "_gid":"GA1.2.1552723320.1594148642",
    ".Cnblogs.AspNetCore.Cookies":"",
}
url ="https://www.cnblogs.com/Renyi-Fan/p/13277298.html"
response = requests.get(url,headers=headers,cookies=cookies)
print(response.status_code)
print(response.text)
# Out:
# 200
# <!DOCTYPE html>
# <html lang="zh-cn">
# <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <meta name="referrer" content="origin" />
#     <meta property="og:description" content="测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试" />
#     <meta http-equiv="Cache-Control" content="no-transform" />
#     <meta http-equiv="Cache-Control" content="no-siteapp" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#     <title>test标题 - 范仁义 - 博客园</title>
#     <link id="favicon" rel="shortcut icon" href="//common.cnblogs.com/favicon.ico?v=20200522" type="image/x-icon" />
#
#     <link rel="stylesheet" href="https://www.cnblogs.com/css/blog-common.min.css" />
#     <link id="MainCss" rel="stylesheet" href="https://www.cnblogs.com/skins/coffee/bundle-coffee.min.css" />
#     <link type="text/css" rel="stylesheet" href="https://www.cnblogs.com/Renyi-Fan/custom.css?v=ZuLVaYPhkkb&#x2B;Lqcsm9A8nA281Rg=" />
#     <link id="mobile-style" media="only screen and (max-width: 767px)" type="text/css" rel="stylesheet" href="https://www.cnblogs.com/skins/coffee/bundle-coffee-mobile.min.css" />
#
#     <link type="application/rss+xml" rel="alternate" href="https://www.cnblogs.com/Renyi-Fan/rss" />
#     <link type="application/rsd+xml" rel="EditURI" href="https://www.cnblogs.com/Renyi-Fan/rsd.xml" />
#     <link type="application/wlwmanifest+xml" rel="wlwmanifest" href="https://www.cnblogs.com/Renyi-Fan/wlwmanifest.xml" />
#     <script src="https://common.cnblogs.com/scripts/jquery-2.2.0.min.js"></script>
#     <script src="https://www.cnblogs.com/js/blog-common.min.js"></script>
#     <script>
#         var currentBlogId = 354844;
#         var currentBlogApp = 'Renyi-Fan';
#         var cb_enable_mathjax = false;
#         var isLogined = true;
#         var skinName = 'coffee';
#     </script>
#
#
#
# </head>
# <body>
#     <a name="top"></a>
#     <div id="page_begin_html">
#         <div id="pay_area" >
#     <div id="pay_pic" >
#         <img name="pay_image_" src="https://images.cnblogs.com/cnblogs_com/Renyi-Fan/1188097/o_fry4.png">
#     </div>
#     <div align="center">微信扫一扫打赏支持</div>
# </div>
#     </div>
#
# <!--done-->
# <div id="home">
# <div id="header">
# 	<div id="blogTitle">
# 	<a href="https://www.cnblogs.com/Renyi-Fan/"><img id="blogLogo" src="/skins/custom/images/logo.gif" alt="返回主页" /></a>
#
# <!--done-->
# <h1><a id="Header1_HeaderTitle" class="headermaintitle HeaderMainTitle" href="https://www.cnblogs.com/Renyi-Fan/">范仁义</a>
# </h1>
# <h2>
# 个人简介：本科：西南大学，专业第一，每年国奖，加拿大留学交换，建模（美赛二等奖，国赛特等奖）。
# 喜欢挑战，酷爱难的东西。
# 第一份工作：华东师大图书馆自动化部。
# 第二份工作：香港教育大学MIT部门。
# QQ交流群：942327638。
# 学习：大纲+实例、实践+需求、对比+并进、接触+模仿。
# 我的旨在学过的东西不再忘记（主要使用艾宾浩斯遗忘曲线算法及其它智能的学习复习算法）的偏公益性质的完全免费的编程视频学习网站：<a href="https://fanrenyi.com" style="color:#3c8dbc;">fanrenyi.com</a>；有各种前端、后端、算法、大数据、人工智能等课程。
# 聊技术，交朋友，修心境：qq404006308，微信fan404006308
#
# </h2>
#
#
#
#
#
# 	</div><!--end: blogTitle 博客的标题和副标题 -->
# </div><!--end: header 头部 -->
#
# <div id="main">
# 	<div id="mainContent">
# 	<div class="forFlow">
# 		<div id="navigator">
#
# <ul id="navList">
# 	<li><a id="blog_nav_sitehome" class="menu" href="https://www.cnblogs.com/">
# 博客园</a>
# </li>
# 	<li>
# <a id="blog_nav_myhome" class="menu" href="https://www.cnblogs.com/Renyi-Fan/">
# 首页</a>
# </li>
# 	<li>
#
# <a id="blog_nav_newpost" class="menu" href="https://i.cnblogs.com/EditPosts.aspx?opt=1">
# 新随笔</a>
# </li>
# 	<li>
# <a id="blog_nav_contact" class="menu" href="https://msg.cnblogs.com/send/%E8%8C%83%E4%BB%81%E4%B9%89">
# 联系</a></li>
# 	<li>
# <a id="blog_nav_admin" class="menu" href="https://i.cnblogs.com/">
# 管理</a>
# </li>
# 	<li>
# <a id="blog_nav_rss" class="menu" href="javascript:void(0)" data-rss="https://www.cnblogs.com/Renyi-Fan/rss/">
# 订阅</a>
#
# <a id="blog_nav_rss_image" href="https://www.cnblogs.com/Renyi-Fan/rss/">
#     <img src="/skins/coffee/images/xml.gif" alt="订阅" />
# </a></li>
# </ul>
#
#
#
# 			<div class="blogStats">
#
# 				<!--done-->
# 随笔-
# 4264&nbsp;
# 文章-
# 0&nbsp;
# 评论-
# 238&nbsp;
#
#
#
#
# 			</div><!--end: blogStats -->
# 		</div><!--end: navigator 博客导航栏 -->
# 		<div id="post_detail">
# <!--done-->
# <div id="topics">
# 	<div class="post">
# 		<h1 class = "postTitle">
#
# <a id="cb_post_title_url" class="postTitle2 vertical-middle" href="https://www.cnblogs.com/Renyi-Fan/p/13277298.html">
#     <span>test标题</span>
#
#
#
# </a>
#
# 		</h1>
# 		<div class="clear"></div>
# 		<div class="postBody">
#
# <div id="cnblogs_post_body" class="blogpost-body ">
#     <p>测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试测试</p>
# </div>
# <div id="MySignature"></div>
# <div class="clear"></div>
# <div id="blog_post_info_block">
#     <div id="blog_post_info"></div>
#     <div class="clear"></div>
#     <div id="post_next_prev"></div>
# </div>
# 		</div>
# 		<div class="postDesc">posted @
# <span id="post-date">2020-07-10 02:50</span>&nbsp;
# <a href="https://www.cnblogs.com/Renyi-Fan/">范仁义</a>&nbsp;
# 阅读(<span id="post_view_count">...</span>)&nbsp;
# 评论(<span id="post_comment_count">...</span>)&nbsp;
# <a href="https://i.cnblogs.com/EditPosts.aspx?postid=13277298" rel="nofollow">编辑(未发布)</a>&nbsp;
# <a href="javascript:void(0)" onclick="AddToWz(13277298);return false;">收藏</a></div>
# 	</div>
#
#
# </div><!--end: topics 文章、评论容器-->
# <script src="https://common.cnblogs.com/highlight/9.12.0/highlight.min.js"></script>
# <script>markdown_highlight();</script>
# <script>
#     var allowComments = true, cb_blogId = 354844, cb_blogApp = 'Renyi-Fan', cb_blogUserGuid = '95b22970-55ce-43b9-6768-08d496e65ef5';
#     var cb_entryId = 13277298, cb_entryCreatedDate = '2020-07-10 02:50', cb_postType = 1;
#     loadViewCount(cb_entryId);
#     loadSideColumnAd();
# </script><a name="!comments"></a>
# <div id="blog-comments-placeholder"></div>
# <script>
#     var commentManager = new blogCommentManager();
#     commentManager.renderComments(0);
# </script>
# <div id="comment_form" class="commentform">
#     <a name="commentform"></a>
#     <div id="divCommentShow"></div>
#     <div id="comment_nav"><span id="span_refresh_tips"></span><a href="javascript:void(0);" onclick="return RefreshCommentList();" id="lnk_RefreshComments" runat="server" clientidmode="Static">刷新评论</a><a href="#" onclick="return RefreshPage();">刷新页面</a><a href="#top">返回顶部</a></div>
#     <div id="comment_form_container"></div>
#     <div class="ad_text_commentbox" id="ad_text_under_commentbox"></div>
#     <div id="ad_t2"></div>
#     <div id="opt_under_post"></div>
#     <div id="cnblogs_c1" class="c_ad_block">
#         <div id='div-gpt-ad-1592365906576-0' style='width: 300px; height: 250px;'></div>
#     </div>
#
#     <div id="cnblogs_c2" class="c_ad_block">
#         <div id='div-gpt-ad-1592366332455-0' style='width: 468px; height: 60px;'></div>
#     </div>
#     <div id="under_post_kb"></div>
#     <div id="HistoryToday" class="c_ad_block"></div>
#     <script type="text/javascript">
#         fixPostBody();
#         deliverBigBanner();
#         deliverT2();
#         deliverC1C2();
#         loadNewsAndKb();
#         loadBlogSignature();
# LoadPostCategoriesTags(cb_blogId, cb_entryId);        LoadPostInfoBlock(cb_blogId, cb_entryId, cb_blogApp, cb_blogUserGuid);
#         GetPrevNextPost(cb_entryId, cb_blogId, cb_entryCreatedDate, cb_postType);
#         loadOptUnderPost();
#         GetHistoryToday(cb_blogId, cb_blogApp, cb_entryCreatedDate);
#     </script>
# </div></div>
#
#
# 	</div><!--end: forFlow -->
# 	</div><!--end: mainContent 主体内容容器-->
#
# 	<div id="sideBar">
# 		<div id="sideBarMain">
#
# <div id="sidebar_news" class="newsItem">
#             <script>loadBlogNews();</script>
# </div>
#
# <div id="sidebar_ad"></div>
# 			<div id="calendar"><div id="blog-calendar" style="display:none"></div><script>loadBlogDefaultCalendar();</script></div>
#
# 			<DIV id="leftcontentcontainer">
# 				<div id="blog-sidecolumn"></div>
#                     <script>loadBlogSideColumn();</script>
# 			</DIV>
#
# 		</div><!--end: sideBarMain -->
# 	</div><!--end: sideBar 侧边栏容器 -->
# 	<div class="clear"></div>
# 	</div><!--end: main -->
# 	<div class="clear"></div>
# 	<div id="footer">
# 		<!--done-->
# Copyright &copy; 2020 范仁义
# <br /><span id="poweredby">Powered by .NET Core on Kubernetes</span>
#
#
#
# 	</div><!--end: footer -->
# </div><!--end: home 自定义的最大容器 -->
#
#
#     <div id="page_end_html">
#         <!--数学公式math jax-->
#  <script type="text/x-mathjax-config">
#         MathJax.Hub.Config({
#         tex2jax: { inlineMath: [['$$','$$'], ['\\(','\\)']], processClass: 'math', processEscapes: true },
#         TeX: {
#         equationNumbers: { autoNumber: ['AMS'], useLabelIds: true },
#         extensions: ['extpfeil.js', 'mediawiki-texvc.js'],
#         Macros: {bm: "\\boldsymbol"}
#         },
#         'HTML-CSS': { linebreaks: { automatic: true } },
#         SVG: { linebreaks: { automatic: true } }
#         });
#     </script>
#     <script src="https://mathjax.cnblogs.com/2_7_5/MathJax.js?config=TeX-AMS-MML_HTMLorMML&amp;v=20200504"></script>
# <script>
#     //绿色通道打赏
#     $("#green_channel").append('<a id="green_channel_dasang" style="background-color: #e33100;" onclick="mu_fry_reward();" href="javascript:void(0);">打赏</a>');
#   </script>
# <script>
#     //给页面最顶端的副标题留出空间
#     $(function () {
#         var subTitleH2Height=$('#blogTitle > h2').height();
#         $('#header').css({"height":(subTitleH2Height+128)+'px'});
#     });
# </script>
# <!--八、标题动画-->
# <!--PageEndHtml Block Begin-->
# <link href="https://blog-static.cnblogs.com/files/Renyi-Fan/animate.css" rel="stylesheet">
# <script type="text/javascript" src="https://blog-static.cnblogs.com/files/Renyi-Fan/jquery.textillate.js"></script>
# <script type="text/javascript" src="https://blog-static.cnblogs.com/files/Renyi-Fan/jquery.lettering.js"></script>
# <script type="text/javascript" src="https://blog-static.cnblogs.com/files/Renyi-Fan/jquery.fittext.js"></script>
#
# <script>
#  // 动画效果
#  $('#blogTitle h2').textillate({
#     loop: true,
#     autoStart: true,
#     in: {
#     shuffle: false,
#     effect: 'bounce'},
#     out: {
#     effect: 'hinge',
#     delayScale: 1.5,
#     delay: 30,
#     sync: false,
#     shuffle: true,
#     reverse: false,
#     callback: function () {}
#   }
#  });
#
# </script>
# <!--END 八、标题动画-->
#
# <!--七、外部js-->
#
#
# <script type="text/javascript">
# function gotoTop(){
# 			setTimeout(function(){
#
# 					document.documentElement.scrollTop = (document.documentElement.scrollTop*0.1);
# 					document.body.scrollTop = (document.body.scrollTop - document.body.scrollTop*0.1);
# 					var scrollTop = document.documentElement.scrollTop || document.body.scrollTop;
#
# 				if(scrollTop > 0){
# 					gotoTop();
# 				}
# 			},10);
# 		}
#
#
#
# var Ftimer = setInterval (Ftoggle,1000),
#       contral = [false,false];
#
# function Ftoggle(){
# 	var tagObjbox = document.getElementsByClassName('catListTag')[0],
#               tagObj = tagObjbox.getElementsByTagName('li'),
#               navList = document.getElementById('navList');
#
#     if(tagObjbox && tagObj){
#        contral[1]=true;
#     	SlideTag(tagObj);
#     }
#     if(navList){
#        contral[2]=true;
#        AddLi(navList);
#     }
#
#     if(contral[1] & contral[2]){
#        clearInterval(Ftimer);
#     }
# }
#
# function AddLi(e){
# 	var li = document.createElement('li'),
# 		a = document.createElement('a');
#
# 	a.innerHTML = '目录';
# 	a.className = 'menu';
# 	a.href = 'http://www.cnblogs.com/Glunefish/p/';
# 	li.appendChild(a);
# 	e.appendChild(li);
#
#
# }
#
# function SlideTag(tagObj){
#
#             offset = true;
#
#         PreSeting();
#
# 	for(var i=0;i<tagObj.length;i++){
# 		(function(i){
# 			tagObj[i].onmouseover = function(){
# 			offset = false;
# 			index = parseInt(this.style.zIndex);
# 			this.style.zIndex = 9999;
# 			}
# 			tagObj[i].onmouseout = function(){
# 			offset = true;
# 			this.style.zIndex = index;
# 			}
# 		})(i);
# 	}
#
# 	setInterval(PreSeting,5000)
#
# 	function F_getSJS(x,y,z){
#
# 		var int = null;
#
# 		if(!z) { z = 6}
#
# 		while(int >= x || int <= y || int === null){
# 			int = Math.random();
# 			int = (int.toFixed(z) * x).toFixed(0);
# 		}
# 		return int;
# 	}
#
# 	function PreSeting(){
#              if(offset){
# 		for(var i=0;i<tagObj.length;i++){
# 			tagObj[i].style.left = F_getSJS(100,30,10)  + 'px';
# 			tagObj[i].style.top = F_getSJS(200,30,10) + 'px';
# 			tagObj[i].style.backgroundColor = 'rgb(' + F_getSJS(256,-1,5) + ',' + F_getSJS(256,-1,10) + ',' + F_getSJS(256,-1,15) + ')';
# 			tagObj[i].style.zIndex = F_getSJS(200,0,16);
# 		}
# }
#
# 	}
#
#
# }
#
# onload = function(){
#
# if(location.href == 'http://www.cnblogs.com/Glunefish/' || location.href == 'https://www.cnblogs.com/Glunefish/'){setTimeout(goto,3000);}
#
# function goto(){
# 		 document.getElementById('headbox').style.display = 'block';
#          document.documentElement.scrollTop = document.documentElement.scrollTop + 200;
#          document.body.scrollTop = document.body.scrollTop + 200;
# }
# }
#
#
# /* 鼠标点击特效 */
# var a_idx = 0;
# jQuery(document).ready(function($) {
#     $("body").click(function(e) {
# var a = new Array("（*@ο@*）", "（⊙o⊙）", "★~★", "(*^‧^*)", "（ˇ＾ˇ〉", "~>_<~+", "(≥◇≤)" ,"（*>.<*）", ">_<|||", "→_→", "└(^o^)┘", " (*^__^*)");
# var $i = $("<span></tagObj>").text(a[a_idx]);
#         a_idx = (a_idx + 1) % a.length;
# var x = e.pageX,
#         y = e.pageY;
#         $i.css({
# "z-index": 999999999999999999999999999999999999999999999999999999999999999999999,
# "top": y - 20,
# "left": x,
# "position": "absolute",
# "font-weight": "bold",
# "color": "#ff6651"
#         });
#         $("body").append($i);
#         $i.animate({
# "top": y - 180,
# "opacity": 0
#         },
#         1500,
# function() {
#             $i.remove();
#         });
#     });
# });
#
#
#
# </script>
# <canvas id="c_n29" style="position: fixed; top: 0px; left: 0px; z-index: -1; opacity: 0.5;" width="1680px" height="1050px"></canvas>
# <script type="text/javascript">getFollowStatus('409998f6-8014-e711-845c-ac853d9f53ac')</script>
#
# <!-- 三、页面展开动画-->
# <script>
# function my_unfold(){
# 	width_main=$('#main').width();
# 	height_main=$('#main').height();
# 	time=1000;
# 	function unfoldLeft(width,height,time) {
# 	    $('#main').animate({
# 	        'width': '0%',
# 	        'height': '0%',
# 	        opacity: '0'
# 	    }, 0,'linear');
# 	    $('#main').animate({
# 	        'width': '+'+width_main,
# 	        'height': '+'+height_main,
# 	        opacity: '1'
# 	    }, time,'linear');
# 	}
# 	unfoldLeft(width_main,height_main,time);
# }
# </script>
# <!--END 七、外部js-->
# <!--END 三、页面展开动画-->
# <!-- 二、回到顶部和展开侧边栏 -->
# <script>
# $('#main').append('<div id="fry_append"><div id="fry_sidebar">侧边栏</div><hr/><div id="fry_reward">打赏</div><hr/><div id="fry_top"><a href="#_labelTop" target="_self">目录</a></div></div>');
# $('#fry_sidebar').click(function(){
# 	$('#mainContent .forFlow').css({'margin-right':'0px'});
# 	if($('#sideBar').css('display')=='none'){
# 		var width=$(window).width()*0.9;
# 		var width1=$(window).width()*0.9-300;
# 		var width2=($(window).width()-280)/2;
# 		if(width*0.35<230){
# 		        $('#mainContent').css({'display':'none'});
# 		        $('#sideBar').css({'display':'block','width':'280','margin-right':width2+'px'});
# 		}else{
# 		        $('#sideBar').css({'display':'block','width':'280px','margin':'none','float':'right'});
# 		        $('#mainContent').css({'display':'block','width':width1+'px'});
# 		}
# 	}
# 	else{
# 		$('#sideBar').css({'display':'none'});
# 		$('#mainContent').css({'display':'block','width':'100%'});
# 	}
# });
# $('#fry_top').click(function(){
# 	var href=$('#fry_top a').attr('href');
# 	document.location=href;
# });
# var fry_pay_area_distance=0;
# $('#fry_reward').click(function(){
# 	var distance=$(window).scrollTop();
#         distance+=$(window).height()/2;
#         distance-=120;
#         $('#pay_area').css({'top':distance+'px','scrollLeft':'50%'});
#         if(fry_pay_area_distance!=distance){$('#pay_area').show();}else{$('#pay_area').toggle();}
#         fry_pay_area_distance=distance;
# });
#
# </script>
#
#
# <!-- 自动生成目录 -->
# <script language="javascript" type="text/javascript">
#     // 生成目录索引列表
#     // ref: http://www.cnblogs.com/wangqiguo/p/4355032.html
#     // modified by: zzq
#     // ref: https://www.cnblogs.com/zzqcn/p/4657124.html
#     // modified by: fry
#     function GenerateContentList() {
#         var mainContent = $('#cnblogs_post_body');
#         var h2_list = $('#cnblogs_post_body h2');//如果你的章节标题不是h2,只需要将这里的h2换掉即可
#
#         if (mainContent.length < 1)
#             return;
#
#         if (h2_list.length > 0) {
#             var content = '<a name="_labelTop"></a>';
#             content += '<div id="navCategory">';
#             content += '<p ><h2 class="mulu_">目录</h2></p>';
#             content += '<ul class="mulu_ul1">';
#             for (var i = 0; i < h2_list.length; i++) {
#                 var go_to_top = '<div style="text-align: right"><a href="#_labelTop">回到顶部</a><a name="_label' + i + '"></a></div>'; //在h2上添加回到顶部
#                 $(h2_list[i]).before(go_to_top);
#
#                 //var h3_list = $(h2_list[i]).nextAll("h3").add($(h2_list[i]).find("h3"));
#                 //var h3_list = $("#cnblogs_post_body h3");
#                 //var h3_list = $(h2_list[i]).nextAll("h3").add($("#cnblogs_post_body h3"));
#                 var h3_list = $(h2_list[i]).nextAll("h3");
#                 //var fry__ = $("#cnblogs_post_body h3").length;
#                 var li3_content = '';
#                 for (var j = 0; j < h3_list.length; j++) {
#                     var tmp = $(h3_list[j]).prevAll('h2').first();
#                     if (!tmp.is(h2_list[i]))
#                         break;
#                     var li3_anchor = '<a name="_label' + i + '_' + j + '"></a>';
#                     $(h3_list[j]).before(li3_anchor);
#                     li3_content += '<li class="mulu2li"><a  href="#_label' + i + '_' + j + '">'
#                         + $(h3_list[j]).text() + '</a></li>';
#                 }
#
#                 var li2_content = '';
#                 if (li3_content.length > 0)
#                     li2_content = '<li class="mulu1li"><a href="#_label' + i + '">'
#                         + $(h2_list[i]).text() + '</a><ul class="mulu_ul2">' + li3_content
#                         + '</ul></li>';
#                 else
#                     li2_content = '<li class="mulu1li"><a href="#_label' + i + '">'
#                         + $(h2_list[i]).text() + '</a></li>';
#                 content += li2_content;
#             }
#             content += '</ul>';
#             content += '</div><p>&nbsp;</p>';
#             /* content += '<p style="font-size:18px"><b>正文</b></p>'; */
#             if ($('#cnblogs_post_body').length != 0) {
#                 $($('#cnblogs_post_body')[0]).prepend(content);
#             }
#         } else { //当页面没有h2标签而有h3标签的时候：就去检索h3和h4
#             var h3_list = $('#cnblogs_post_body h3'); //获取h3
#             if (h3_list.length > 0) {
#                 var content = '<a name="_labelTop"></a>';
#                 content += '<div id="navCategory">';
#                 content += '<p ><h2 class="mulu_">目录</h2></p>';
#                 content += '<ul class="mulu_ul1">';
#                 for (var i = 0; i < h3_list.length; i++) {
#                     var go_to_top = '<div style="text-align: right"><a href="#_labelTop">回到顶部</a><a name="_label' + i + '"></a></div>';
#                     $(h3_list[i]).before(go_to_top); //在每个h3之前添加回到顶部
#
#                     //var h4_list = $(h3_list[i]).nextAll("h4").add($(h3_list[i]).find("h3"));; //获取每个h3下面的h4
#                     var h4_list = $(h3_list[i]).nextAll("h4")
#                     var li4_content = '';
#                     for (var j = 0; j < h4_list.length; j++) {
#                         var tmp = $(h4_list[j]).prevAll('h3').first();
#                         if (!tmp.is(h3_list[i]))
#                             break;
#                         var li4_anchor = '<a name="_label' + i + '_' + j + '"></a>'; //添加锚点
#                         $(h4_list[j]).before(li4_anchor);
#                         li4_content += '<li class="mulu1li"><a href="#_label' + i + '_' + j + '">'
#                             + $(h4_list[j]).text() + '</a></li>'; //链接到锚点
#                     }
#
#                     var li3_content = '';
#                     if (li4_content.length > 0)
#                         li3_content = '<li class="mulu2li"><a  href="#_label' + i + '">'
#                             + $(h3_list[i]).text() + '</a><ul class="mulu_ul2">'
#                             + li4_content + '</ul></li>';
#                     else
#                         li3_content = '<li class="mulu2li"><a href="#_label' + i + '">'
#                             + $(h3_list[i]).text() + '</a></li>';
#                     content += li3_content;
#                 }
#                 content += '</ul>';
#                 content += '</div><p>&nbsp;</p>';
#                 /* content += '<p style="font-size:18px"><b>正文</b></p>'; */
#                 if ($('#cnblogs_post_body').length != 0) {
#                     $($('#cnblogs_post_body')[0]).prepend(content);
#                 }
#
#             }
#
#         }
#
#         var qqinfo = '<div id="mu_fry_reward" onclick="mu_fry_reward()">打赏</div><div style="clear:both;"></div>';
#         $(mainContent[0]).prepend(qqinfo);
#
#         var title_h1 = $('#cnblogs_post_body h1');//将标题信息插入到开头
#         $(mainContent[0]).prepend(title_h1[0]);
#     }
#
#     GenerateContentList();//运行这个js函数
# </script>
# <!-- 一、总结折叠 -->
# <script type="text/javascript">
# 	$('#cnblogs_post_body h2').each(function(i){
# 		//1、获取索引号
# 		summary_index=null;
# 		var s_str=this.innerHTML.trim();
# 		s_str=s_str.replace(/[^\u4e00-\u9fa5]/gi,'');
# 		if(s_str=='一总结'){
# 			summary_index=i;
# 			return false;
# 		}
# 	});
# 	//2、将索引号对应的孩子全部放到一个总结div中去
# 	if(summary_index){
# 		$('#cnblogs_post_body h2').eq(summary_index).nextUntil('h2').addClass('mulu_summary');
# 		$('#cnblogs_post_body h2').eq(summary_index).nextUntil('h2').wrapAll('<div id="mulu_summary"></div>');
# 		//4、设置这个div为隐藏
# 		$('#mulu_summary').hide();
# 		$('.mulu_summary').hide();
# 		//让总结最开始就显示
# 		$('#mulu_summary').show();
# 		$('.mulu_summary').show();
# 	//3、给这个h2添加a标签，添加事件，并且修改里面的文字
# 	$('#cnblogs_post_body h2').eq(summary_index).html('一、总结（点击显示或隐藏总结内容）');
# 	$('#cnblogs_post_body h2').eq(summary_index).prepend('<span class="fry_summary_icon">&gt;&nbsp;&nbsp;</span>');
# 	$('#cnblogs_post_body h2').eq(summary_index).addClass("fry_summary");
#
# 	}
#
# 	//5、写一个函数，来设置这个div为显示
# 	$('.fry_summary').click(function(){
# 		$('#mulu_summary').toggle();
# 		$('.mulu_summary').toggle();
# 		if($('#mulu_summary').css('display')=='none'){
# 			$('.fry_summary_icon').html('<span class="fry_summary_icon">&gt;&nbsp;&nbsp;</span>');
# 		}else{
# 			$('.fry_summary_icon').html('<span class="fry_summary_icon">v &nbsp;&nbsp;</span>');
# 		}
# 	});
# 	//6、目录里面的链接都能让总结显示
# 	$("[class^='mulu']").click(function(){
# 		$('#mulu_summary').show();
# 		$('.mulu_summary').show();
# 		$('.fry_summary_icon').html('<span class="fry_summary_icon">v &nbsp;&nbsp;</span>');
# 	});
#
# </script>
# <!--END 一、总结折叠 -->
# <!-- 四、手机时打赏悬浮框边的比较透明-->
# <script>
# width=$(window).width();
# if(width<600){
# 	$('#fry_append').css({
# 		'opacity':'0.5'
# 	})
#     $('#div_digg').css({
#         'opacity':'0.9'
#     });
# }
# </script>
# <!-- 四、手机时打赏悬浮框边的比较透明-->
# <!--五、目录中的打赏 -->
# <script>
#
# function mu_fry_reward(){
# 	var distance=$(window).scrollTop();
#         distance+=$(window).height()/2;
#         distance-=120;
#         $('#pay_area').css({'top':distance+'px','scrollLeft':'50%'});
#         if(fry_pay_area_distance!=distance){$('#pay_area').show();}else{$('#pay_area').toggle();}
#         fry_pay_area_distance=distance;
# }
# </script>
# <!--END 五、目录中的打赏 -->
# <!--获取相关推荐-->
# <script>
#     $(function () {
#         function addRecommend(){
#             $('#EntryTag>a').each(function () {
#                 var needUrl=$(this).attr('href');
#                 console.log(needUrl);
#                 $("#fry_recommend").load(needUrl+" #myposts");
#                 if(needUrl) clearInterval(fry_t);
#             });
#         }
#         var fry_t=setInterval(addRecommend,1000);
#     });
# </script>
# <!--<script type="text/javascript" src="https://blog-static.cnblogs.com/files/Renyi-Fan/forbidion_ctrl.js"></script>-->
#
# <!-- Fireworks-->
# <script type ="text/javascript" src ="https://blog-static.cnblogs.com/files/Renyi-Fan/fireworks-anime.min.js"></script>
# <script type ="text/javascript" src ="https://blog-static.cnblogs.com/files/Renyi-Fan/fireworks-fireworks-modify.js"></script>
# <!-- END Fireworks-->
#     </div>
# </body>
# </html>
