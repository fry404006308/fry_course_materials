# %%
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
import time
from matplotlib import pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3 import PPO

from gym.wrappers import GrayScaleObservation

from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
import numpy as np
import os
from stable_baselines3.common.callbacks import BaseCallback

env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)


log_dir = './monitor_log/'
os.makedirs(log_dir, exist_ok=True)

env = Monitor(env, log_dir)

env = GrayScaleObservation(env,keep_dim=True)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env,4,channels_order='last')

# %%
class SaveOnStepCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq, save_path, verbose=1):
        super(SaveOnStepCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = os.path.join(save_path, 'best_model')
        

    def _init_callback(self):
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            self.model.save(os.path.join(self.save_path,'_{}'.format(self.n_calls)))
        
        return True

# %%
learning_rate = 1e-6
n_steps = 2048


tensorboard_log = r'./tensorboard_logs/'
model = PPO("CnnPolicy", env, verbose=1,
            learning_rate=learning_rate,n_steps=n_steps,
            tensorboard_log=tensorboard_log)

save_path=r"F:\\RL_Mario\\"
callback1=SaveOnStepCallback(check_freq=20000,save_path=save_path)
model.learn(total_timesteps=5000000,callback=callback1)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./tensorboard_logs/PPO_1
# D:\software\e_anaconda\envs\pytorch\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# -----------------------------
# | time/              |      |
# |    fps             | 93   |
# |    iterations      | 1    |
# |    time_elapsed    | 21   |
# |    total_timesteps | 2048 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 72            |
# |    iterations           | 2             |
# |    time_elapsed         | 56            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00010179842 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00362      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 79.4          |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00037      |
# |    value_loss           | 144           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 66            |
# |    iterations           | 3             |
# |    time_elapsed         | 92            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00023726805 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0672        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.137         |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00075      |
# |    value_loss           | 0.345         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 4             |
# |    time_elapsed         | 131           |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00023196003 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00771      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0955        |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000961     |
# |    value_loss           | 0.316         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 60            |
# |    iterations           | 5             |
# |    time_elapsed         | 168           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00014397106 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0149        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.328         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000695     |
# |    value_loss           | 0.61          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 59            |
# |    iterations           | 6             |
# |    time_elapsed         | 206           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 4.8878865e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.082         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 32.8          |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000107     |
# |    value_loss           | 96.4          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 58            |
# |    iterations           | 7             |
# |    time_elapsed         | 243           |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 4.7017937e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.251         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.196         |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000116     |
# |    value_loss           | 0.422         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 510          |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 8            |
# |    time_elapsed         | 281          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0003870851 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0111      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0972       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000836    |
# |    value_loss           | 0.307        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 510           |
# | time/                   |               |
# |    fps                  | 57            |
# |    iterations           | 9             |
# |    time_elapsed         | 321           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00010889891 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.167         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 19.7          |
# |    n_updates            | 80            |
# |    policy_gradient_loss | 8.98e-05      |
# |    value_loss           | 59.8          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 510           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 10            |
# |    time_elapsed         | 360           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00014846769 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.372         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 3.97          |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -5.56e-05     |
# |    value_loss           | 33.3          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 510           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 11            |
# |    time_elapsed         | 397           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00046419672 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.879         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.168         |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000715     |
# |    value_loss           | 0.392         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 510           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 12            |
# |    time_elapsed         | 434           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00039633812 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0226       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.074         |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000696     |
# |    value_loss           | 0.182         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 510           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 13            |
# |    time_elapsed         | 472           |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00043613417 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.522         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 22.8          |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000186     |
# |    value_loss           | 64.4          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 510           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 14            |
# |    time_elapsed         | 509           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00048331858 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.49          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 8.01          |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000616     |
# |    value_loss           | 37.7          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 510           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 15            |
# |    time_elapsed         | 543           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00036760324 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.631         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.233         |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000417     |
# |    value_loss           | 0.787         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 493           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 16            |
# |    time_elapsed         | 578           |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00016678739 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.596         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.07          |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -7.33e-05     |
# |    value_loss           | 0.359         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 493           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 17            |
# |    time_elapsed         | 613           |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00022093591 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.6           |
# |    learning_rate        | 1e-06         |
# |    loss                 | 16.4          |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -3.34e-05     |
# |    value_loss           | 59            |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 493           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 18            |
# |    time_elapsed         | 648           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00012937843 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | 0.658         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 5.04          |
# |    n_updates            | 170           |
# |    policy_gradient_loss | 5.49e-05      |
# |    value_loss           | 46.3          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 493          |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 19           |
# |    time_elapsed         | 683          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0015601851 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.7          |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0859       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 0.273        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 493           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 20            |
# |    time_elapsed         | 719           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00067680184 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | -0.112        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0795        |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.000823     |
# |    value_loss           | 0.206         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.38e+04      |
# |    ep_rew_mean          | 632           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 21            |
# |    time_elapsed         | 756           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00033866215 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | 0.783         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 11.9          |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000635     |
# |    value_loss           | 46.8          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.38e+04     |
# |    ep_rew_mean          | 632          |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 22           |
# |    time_elapsed         | 794          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0003210063 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.714        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 39.1         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000342    |
# |    value_loss           | 95.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.38e+04     |
# |    ep_rew_mean          | 632          |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 23           |
# |    time_elapsed         | 831          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0006135469 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.766        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 70.5         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000594    |
# |    value_loss           | 107          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.38e+04     |
# |    ep_rew_mean          | 632          |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 24           |
# |    time_elapsed         | 869          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0018878896 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | -0.121       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0362       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 0.741        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.38e+04     |
# |    ep_rew_mean          | 632          |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 25           |
# |    time_elapsed         | 906          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 5.178855e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 2            |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000159    |
# |    value_loss           | 31.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+04    |
# |    ep_rew_mean          | 632         |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 26          |
# |    time_elapsed         | 942         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004040206 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.488       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00315    |
# |    value_loss           | 1.72        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.37e+04      |
# |    ep_rew_mean          | 791           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 27            |
# |    time_elapsed         | 978           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00025260833 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.88         |
# |    explained_variance   | 0.761         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 21            |
# |    n_updates            | 260           |
# |    policy_gradient_loss | 4.94e-05      |
# |    value_loss           | 61.1          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.37e+04      |
# |    ep_rew_mean          | 791           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 28            |
# |    time_elapsed         | 1015          |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00021736507 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.87         |
# |    explained_variance   | 0.819         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 28.4          |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000245     |
# |    value_loss           | 90.3          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.37e+04      |
# |    ep_rew_mean          | 791           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 29            |
# |    time_elapsed         | 1049          |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00015981309 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.87         |
# |    explained_variance   | 0.817         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 12.2          |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000335     |
# |    value_loss           | 28.7          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.37e+04    |
# |    ep_rew_mean          | 791         |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 30          |
# |    time_elapsed         | 1085        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.004287295 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0903      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00271    |
# |    value_loss           | 1.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.37e+04    |
# |    ep_rew_mean          | 791         |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 31          |
# |    time_elapsed         | 1119        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.001636615 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.101       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00124    |
# |    value_loss           | 1.3         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.37e+04      |
# |    ep_rew_mean          | 791           |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 32            |
# |    time_elapsed         | 1153          |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00016593709 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.88         |
# |    explained_variance   | 0.812         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 27.5          |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000401     |
# |    value_loss           | 54.1          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.37e+04     |
# |    ep_rew_mean          | 791          |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 33           |
# |    time_elapsed         | 1187         |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0022098706 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.896        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.201        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00237     |
# |    value_loss           | 0.386        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.37e+04     |
# |    ep_rew_mean          | 791          |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 34           |
# |    time_elapsed         | 1222         |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0003633223 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.0198       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.149        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000291    |
# |    value_loss           | 0.275        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.37e+04     |
# |    ep_rew_mean          | 791          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 35           |
# |    time_elapsed         | 1256         |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0023977351 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.186        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00244     |
# |    value_loss           | 0.318        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.45e+04     |
# |    ep_rew_mean          | 825          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 36           |
# |    time_elapsed         | 1290         |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0002675297 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 40.6         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000147    |
# |    value_loss           | 68.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.45e+04     |
# |    ep_rew_mean          | 825          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 37           |
# |    time_elapsed         | 1324         |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0004350581 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 26.5         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000476    |
# |    value_loss           | 115          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.45e+04     |
# |    ep_rew_mean          | 825          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 38           |
# |    time_elapsed         | 1359         |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0014017555 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.862        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0647       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 0.287        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.45e+04     |
# |    ep_rew_mean          | 825          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 39           |
# |    time_elapsed         | 1393         |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0021404978 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.819        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.125        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 0.353        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.45e+04     |
# |    ep_rew_mean          | 825          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 40           |
# |    time_elapsed         | 1428         |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0008465318 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.101        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000505    |
# |    value_loss           | 0.346        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.45e+04     |
# |    ep_rew_mean          | 825          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 41           |
# |    time_elapsed         | 1460         |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 1.997422e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.92         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 29.2         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -2.56e-05    |
# |    value_loss           | 48.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.45e+04     |
# |    ep_rew_mean          | 825          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 42           |
# |    time_elapsed         | 1495         |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0035748007 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.487        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.14         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00245     |
# |    value_loss           | 0.353        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.45e+04     |
# |    ep_rew_mean          | 825          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 43           |
# |    time_elapsed         | 1530         |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0015392425 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.022        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0668       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000849    |
# |    value_loss           | 0.265        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.45e+04      |
# |    ep_rew_mean          | 825           |
# | time/                   |               |
# |    fps                  | 57            |
# |    iterations           | 44            |
# |    time_elapsed         | 1565          |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 5.0315517e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.86         |
# |    explained_variance   | 0.698         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 34.5          |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000319     |
# |    value_loss           | 47.1          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.45e+04     |
# |    ep_rew_mean          | 825          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 45           |
# |    time_elapsed         | 1601         |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0005745158 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | 0.929        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 20.6         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000308    |
# |    value_loss           | 59.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.45e+04     |
# |    ep_rew_mean          | 825          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 46           |
# |    time_elapsed         | 1636         |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0026364732 |
# |    clip_fraction        | 0.00127      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.86        |
# |    explained_variance   | 0.879        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0938       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 0.486        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.45e+04     |
# |    ep_rew_mean          | 825          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 47           |
# |    time_elapsed         | 1671         |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0006548436 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.0896       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0819       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000288    |
# |    value_loss           | 0.171        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+04     |
# |    ep_rew_mean          | 768          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 48           |
# |    time_elapsed         | 1707         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0019195722 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.774        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0838       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00134     |
# |    value_loss           | 0.191        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+04     |
# |    ep_rew_mean          | 768          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 49           |
# |    time_elapsed         | 1743         |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 7.087487e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.893        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 36.1         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.000249     |
# |    value_loss           | 69.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+04     |
# |    ep_rew_mean          | 768          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 50           |
# |    time_elapsed         | 1779         |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0029316568 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.83         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.21         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 1.81         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+04     |
# |    ep_rew_mean          | 768          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 51           |
# |    time_elapsed         | 1814         |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0022207156 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.294        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 1.09         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+04     |
# |    ep_rew_mean          | 768          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 52           |
# |    time_elapsed         | 1851         |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0003766673 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.881        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.294        |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000546    |
# |    value_loss           | 1.91         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+04     |
# |    ep_rew_mean          | 768          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 53           |
# |    time_elapsed         | 1886         |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 5.075548e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 33.3         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.000124    |
# |    value_loss           | 66           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+04     |
# |    ep_rew_mean          | 768          |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 54           |
# |    time_elapsed         | 1922         |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0023478125 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.573        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0968       |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 0.946        |
# ------------------------------------------
# ...
# |    explained_variance   | 0.793         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 170           |
# |    n_updates            | 7860          |
# |    policy_gradient_loss | -0.000155     |
# |    value_loss           | 482           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.15e+03      |
# |    ep_rew_mean          | 1.98e+03      |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 788           |
# |    time_elapsed         | 28432         |
# |    total_timesteps      | 1613824       |
# | train/                  |               |
# |    approx_kl            | 0.00031318766 |
# |    clip_fraction        | 0.00166       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.379        |
# |    explained_variance   | 0.791         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 129           |
# |    n_updates            | 7870          |
# |    policy_gradient_loss | -0.000247     |
# |    value_loss           | 481           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.13e+03     |
# |    ep_rew_mean          | 1.96e+03     |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 789          |
# |    time_elapsed         | 28471        |
# |    total_timesteps      | 1615872      |
# | train/                  |              |
# |    approx_kl            | 0.0010034062 |
# |    clip_fraction        | 0.00161      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.382       |
# |    explained_variance   | 0.858        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 246          |
# |    n_updates            | 7880         |
# |    policy_gradient_loss | -0.000619    |
# |    value_loss           | 391          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.13e+03     |
# |    ep_rew_mean          | 1.95e+03     |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 790          |
# |    time_elapsed         | 28512        |
# |    total_timesteps      | 1617920      |
# | train/                  |              |
# |    approx_kl            | 0.0010838478 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.358       |
# |    explained_variance   | 0.78         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 141          |
# |    n_updates            | 7890         |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 484          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.13e+03      |
# |    ep_rew_mean          | 1.95e+03      |
# | time/                   |               |
# |    fps                  | 56            |
# |    iterations           | 791           |
# |    time_elapsed         | 28552         |
# |    total_timesteps      | 1619968       |
# | train/                  |               |
# |    approx_kl            | 0.00012250186 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.363        |
# |    explained_variance   | 0.846         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 105           |
# |    n_updates            | 7900          |
# |    policy_gradient_loss | -0.000184     |
# |    value_loss           | 458           |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.13e+03  |
# |    ep_rew_mean          | 1.95e+03  |
# | time/                   |           |
# |    fps                  | 56        |
# |    iterations           | 792       |
# |    time_elapsed         | 28597     |
# |    total_timesteps      | 1622016   |
# | train/                  |           |
# |    approx_kl            | 0.0028822 |
# |    clip_fraction        | 0.0277    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.679    |
# |    explained_variance   | 0.865     |
# |    learning_rate        | 1e-06     |
# |    loss                 | 328       |
# |    n_updates            | 7910      |
# |    policy_gradient_loss | -0.00186  |
# |    value_loss           | 601       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | 1.95e+03    |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 793         |
# |    time_elapsed         | 28637       |
# |    total_timesteps      | 1624064     |
# | train/                  |             |
# |    approx_kl            | 0.011874962 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 80.6        |
# |    n_updates            | 7920        |
# |    policy_gradient_loss | -0.00279    |
# |    value_loss           | 175         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | 1.95e+03    |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 794         |
# |    time_elapsed         | 28678       |
# |    total_timesteps      | 1626112     |
# | train/                  |             |
# |    approx_kl            | 0.014722314 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | -1.36       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.227       |
# |    n_updates            | 7930        |
# |    policy_gradient_loss | -0.00396    |
# |    value_loss           | 1.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | 1.95e+03    |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 795         |
# |    time_elapsed         | 28718       |
# |    total_timesteps      | 1628160     |
# | train/                  |             |
# |    approx_kl            | 0.002398559 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | -0.984      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.234       |
# |    n_updates            | 7940        |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 0.762       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.13e+03     |
# |    ep_rew_mean          | 1.95e+03     |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 796          |
# |    time_elapsed         | 28760        |
# |    total_timesteps      | 1630208      |
# | train/                  |              |
# |    approx_kl            | 0.0025539808 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | -0.282       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.218        |
# |    n_updates            | 7950         |
# |    policy_gradient_loss | -0.00244     |
# |    value_loss           | 0.739        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.13e+03     |
# |    ep_rew_mean          | 1.95e+03     |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 797          |
# |    time_elapsed         | 28801        |
# |    total_timesteps      | 1632256      |
# | train/                  |              |
# |    approx_kl            | 0.0043520755 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.758        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 32.1         |
# |    n_updates            | 7960         |
# |    policy_gradient_loss | -0.00237     |
# |    value_loss           | 109          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.13e+03     |
# |    ep_rew_mean          | 1.95e+03     |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 798          |
# |    time_elapsed         | 28840        |
# |    total_timesteps      | 1634304      |
# | train/                  |              |
# |    approx_kl            | 0.0028622553 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | -1.86        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.478        |
# |    n_updates            | 7970         |
# |    policy_gradient_loss | -0.000103    |
# |    value_loss           | 11           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.13e+03     |
# |    ep_rew_mean          | 1.95e+03     |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 799          |
# |    time_elapsed         | 28878        |
# |    total_timesteps      | 1636352      |
# | train/                  |              |
# |    approx_kl            | 0.0006116319 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.54        |
# |    explained_variance   | -0.392       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.11         |
# |    n_updates            | 7980         |
# |    policy_gradient_loss | -0.00117     |
# |    value_loss           | 7.33         |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\RENYIF~1\AppData\Local\Temp/ipykernel_624328/1371844059.py in <module>
#      12 save_path=r"F:\\RL_Mario\\"
#      13 callback1=SaveOnStepCallback(check_freq=20000,save_path=save_path)
# ---> 14 model.learn(total_timesteps=5000000,callback=callback1)
#
# D:\software\e_anaconda\envs\pytorch\lib\site-packages\stable_baselines3\ppo\ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     297     ) -> "PPO":
#     298
# --> 299         return super(PPO, self).learn(
#     300             total_timesteps=total_timesteps,
#     301             callback=callback,
#
# D:\software\e_anaconda\envs\pytorch\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     248         while self.num_timesteps < total_timesteps:
#     249
# --> 250             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     251
#     252             if continue_training is False:
#
# D:\software\e_anaconda\envs\pytorch\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     176                 clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
#     177
# --> 178             new_obs, rewards, dones, infos = env.step(clipped_actions)
#     179
#     180             self.num_timesteps += env.num_envs
#
# D:\software\e_anaconda\envs\pytorch\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in step(self, actions)
#     160         """
#     161         self.step_async(actions)
# --> 162         return self.step_wait()
#     163
#     164     def get_images(self) -> Sequence[np.ndarray]:
#
# D:\software\e_anaconda\envs\pytorch\lib\site-packages\stable_baselines3\common\vec_env\vec_transpose.py in step_wait(self)
#      93
#      94     def step_wait(self) -> VecEnvStepReturn:
# ---> 95         observations, rewards, dones, infos = self.venv.step_wait()
#      96
#      97         # Transpose the terminal observations
#
# D:\software\e_anaconda\envs\pytorch\lib\site-packages\stable_baselines3\common\vec_env\vec_frame_stack.py in step_wait(self)
#      46     ) -> Tuple[Union[np.ndarray, Dict[str, np.ndarray]], np.ndarray, np.ndarray, List[Dict[str, Any]],]:
#      47
# ---> 48         observations, rewards, dones, infos = self.venv.step_wait()
#      49
#      50         observations, infos = self.stackedobs.update(observations, dones, infos)
#
# D:\software\e_anaconda\envs\pytorch\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in step_wait(self)
#      41     def step_wait(self) -> VecEnvStepReturn:
#      42         for env_idx in range(self.num_envs):
# ---> 43             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44                 self.actions[env_idx]
#      45             )
#
# D:\software\e_anaconda\envs\pytorch\lib\site-packages\gym\core.py in step(self, action)
#     280
#     281     def step(self, action):
# --> 282         observation, reward, done, info = self.env.step(action)
#     283         return self.observation(observation), reward, done, info
#     284
#
# D:\software\e_anaconda\envs\pytorch\lib\site-packages\stable_baselines3\common\monitor.py in step(self, action)
#      88         if self.needs_reset:
#      89             raise RuntimeError("Tried to step environment that needs reset")
# ---> 90         observation, reward, done, info = self.env.step(action)
#      91         self.rewards.append(reward)
#      92         if done:
#
# D:\software\e_anaconda\envs\pytorch\lib\site-packages\nes_py\wrappers\joypad_space.py in step(self, action)
#      72         """
#      73         # take the step and record the output
# ---> 74         return self.env.step(self._action_map[action])
#      75
#      76     def reset(self):
#
# D:\software\e_anaconda\envs\pytorch\lib\site-packages\gym\wrappers\time_limit.py in step(self, action)
#      16             self._elapsed_steps is not None
#      17         ), "Cannot call env.step() before calling reset()"
# ---> 18         observation, reward, done, info = self.env.step(action)
#      19         self._elapsed_steps += 1
#      20         if self._elapsed_steps >= self._max_episode_steps:
#
# D:\software\e_anaconda\envs\pytorch\lib\site-packages\nes_py\nes_env.py in step(self, action)
#     291         self.controllers[0][:] = action
#     292         # pass the action to the emulator as an unsigned byte
# --> 293         _LIB.Step(self._env)
#     294         # get the reward for this step
#     295         reward = self._get_reward()
#
# KeyboardInterrupt:
